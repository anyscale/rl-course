# %% [markdown]
# ## Modul 3 Lernergebnisse

# %% [markdown]
# #### Lernergebnisse des Moduls
#
# Am Ende dieses Moduls wirst du in der Lage sein:
#
# - Deine eigene RL-Environment von Grund auf in Python zu erstellen.
# - Bei einem Problem eine geeignete Darstellung des Beobachtungsraums auswählen.
# - Ausgehend von einem Problem eine geeignete Darstellung des Aktionsraums auswählen.
# - Deine Belohnungen so zu gestalten, dass sie das Training verbessern.
# - Erkläre den Begriff "Exploitation" (Ausbeutung) gegenüber "Exploration" (Erforschung) im RL.

# %% [markdown]
# #### Los geht's mit Modul 3!
