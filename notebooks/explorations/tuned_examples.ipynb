# %% [markdown]
# #### ppo/cartpol-ppo

# %%
import ray

# %%
! rllib train --run DQN --env CartPole-v0  # --config '{"framework": "tf2", "eager_tracing": true}' for eager execution
# Out:
# == Status ==
# Current time: 2022-04-04 09:34:17 (running for 00:00:00.13)
# Memory usage on this node: 7.0/8.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/3.17 GiB heap, 0.0/1.58 GiB objects
# Result logdir: /Users/mike/ray_results/default
# Number of trials: 1/1 (1 PENDING)
# +-----------------------------+----------+-------+
# | Trial name                  | status   | loc   |
# |-----------------------------+----------+-------|
# | DQN_CartPole-v0_123f9_00000 | PENDING  |       |
# +-----------------------------+----------+-------+
#
#
# (DQNTrainer pid=40773) 2022-04-04 09:34:23,198	INFO trainer.py:2054 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# ...
